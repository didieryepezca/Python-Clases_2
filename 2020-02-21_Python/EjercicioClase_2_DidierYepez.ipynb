# %%
## IMPORTAMOS LA LIBRERIA PANDAS.

import pandas as pda

pda.Series(np.random.randn(5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-32a4f5db3dd7> in <module>
#       3 import pandas as pda
#       4
# ----> 5 pda.Series(np.random.randn(5))
#
# NameError: name 'np' is not defined

# %%
## 1 Carga de data del .CSV

import sys
sys.path
# Out:
# ['D:\\CERTIFIED BIG DATA DEVELOPER\\2020-01-31_Python',
#  'C:\\ProgramData\\Anaconda3\\python37.zip',
#  'C:\\ProgramData\\Anaconda3\\DLLs',
#  'C:\\ProgramData\\Anaconda3\\lib',
#  'C:\\ProgramData\\Anaconda3',
#  '',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\LENOVO\\.ipython']

# %%
data = pda.read_csv('D:\\CERTIFIED BIG DATA DEVELOPER\\2020-01-31_Python/ChurnTrain.csv', sep=',')
data
# Out:
#       Tamano_cuenta  Plan_Inter  Plan_Voz  Num_Mensajes  Total_min_dia  \
# 0               128         0.0       1.0          25.0          265.1
# 1               107         0.0       1.0          26.0          161.6
# 2               137         0.0       0.0           0.0          243.4
# 3                84         1.0       0.0           0.0          299.4
# 4                75         1.0       0.0           0.0          166.7
# ...             ...         ...       ...           ...            ...
# 3328            192         0.0       1.0          36.0          156.2
# 3329             68         0.0       0.0           0.0          231.1
# 3330             28         0.0       0.0           0.0          180.8
# 3331            184         1.0       0.0           0.0          213.8
# 3332             74         0.0       1.0          25.0          234.4
#
#       Total_llama_dia  Total_cargas_dia  Total_min_manana  Total_llama_manana  \
# ...

# %%
## 2 .... ESTRUCTURA


type(data) 


data.dtypes
# Out:
# Tamano_cuenta           int64
# Plan_Inter            float64
# Plan_Voz              float64
# Num_Mensajes          float64
# Total_min_dia         float64
# Total_llama_dia       float64
# Total_cargas_dia      float64
# Total_min_manana      float64
# Total_llama_manana    float64
# Total_carga_manana    float64
# Total_min_noche       float64
# Total_llama_noche     float64
# Total_carga_noche     float64
# Total_min_Inter       float64
# Total_llama_Inter     float64
# Total_carga_Inter     float64
# Reclamos                int64
# churn                  object
# dtype: object

# %%
## 2 .... DIMENSION
data.shape
# Out:
# (3333, 18)

# %%
## 2 .... DESCRIPCION (RESUMEN)


data.describe().round(2)
# Out:
#        Tamano_cuenta  Plan_Inter  Plan_Voz  Num_Mensajes  Total_min_dia  \
# count        3333.00      3331.0   3330.00       3332.00        3330.00
# mean          101.06         0.1      0.28          8.10         179.76
# std            39.82         0.3      0.45         13.69          54.47
# min             1.00         0.0      0.00          0.00           0.00
# 25%            74.00         0.0      0.00          0.00         143.70
# 50%           101.00         0.0      0.00          0.00         179.40
# 75%           127.00         0.0      1.00         20.00         216.38
# max           243.00         1.0      1.00         51.00         350.80
#
#        Total_llama_dia  Total_cargas_dia  Total_min_manana  \
# count          3330.00           3330.00           3331.00
# mean            100.44             30.56            201.00
# std              20.07              9.26             50.66
# min               0.00              0.00              0.00
# ...

# %%
# 3. TRANSFORMAR A CADENA

data['Plan_Inter'] = data['Plan_Inter'].astype(str)
data['Plan_Inter']
# Out:
# 0       0.0
# 1       0.0
# 2       0.0
# 3       1.0
# 4       1.0
#        ...
# 3328    0.0
# 3329    0.0
# 3330    0.0
# 3331    1.0
# 3332    0.0
# Name: Plan_Inter, Length: 3333, dtype: object

# %%
data['Plan_Voz'] = data['Plan_Voz'].astype(str)
data['Plan_Voz']
# Out:
# 0       1.0
# 1       1.0
# 2       0.0
# 3       0.0
# 4       0.0
#        ...
# 3328    1.0
# 3329    0.0
# 3330    0.0
# 3331    0.0
# 3332    1.0
# Name: Plan_Voz, Length: 3333, dtype: object

# %%
data['Reclamos'] = data['Reclamos'].astype(str)
data['Reclamos']
# Out:
# 0       1
# 1       1
# 2       0
# 3       2
# 4       3
#        ..
# 3328    2
# 3329    3
# 3330    2
# 3331    2
# 3332    0
# Name: Reclamos, Length: 3333, dtype: object

# %%
# 5. PROMEDIO DE COLUMNAS

data.mean()
# Out:
# Tamano_cuenta         101.064806
# Num_Mensajes            8.095138
# Total_min_dia         179.763514
# Total_llama_dia       100.442943
# Total_cargas_dia       30.560201
# Total_min_manana      201.003062
# Total_llama_manana    100.111378
# Total_carga_manana     17.083540
# Total_min_noche       200.889637
# Total_llama_noche     100.108043
# Total_carga_noche       9.040165
# Total_min_Inter        10.236486
# Total_llama_Inter       4.478235
# Total_carga_Inter       2.764581
# Reclamos                     inf
# dtype: float64

# %%
## REEMPLAZAMOS NAN CON EL PROMEDIO MEAN
data.fillna(data.mean())
# Out:
#       Tamano_cuenta Plan_Inter Plan_Voz  Num_Mensajes  Total_min_dia  \
# 0               128        0.0      1.0          25.0          265.1
# 1               107        0.0      1.0          26.0          161.6
# 2               137        0.0      0.0           0.0          243.4
# 3                84        1.0      0.0           0.0          299.4
# 4                75        1.0      0.0           0.0          166.7
# ...             ...        ...      ...           ...            ...
# 3328            192        0.0      1.0          36.0          156.2
# 3329             68        0.0      0.0           0.0          231.1
# 3330             28        0.0      0.0           0.0          180.8
# 3331            184        1.0      0.0           0.0          213.8
# 3332             74        0.0      1.0          25.0          234.4
#
#       Total_llama_dia  Total_cargas_dia  Total_min_manana  Total_llama_manana  \
# ...

# %%
##DATA CON NANS
data
# Out:
#       Tamano_cuenta Plan_Inter Plan_Voz  Num_Mensajes  Total_min_dia  \
# 0               128        0.0      1.0          25.0          265.1
# 1               107        0.0      1.0          26.0          161.6
# 2               137        0.0      0.0           0.0          243.4
# 3                84        1.0      0.0           0.0          299.4
# 4                75        1.0      0.0           0.0          166.7
# ...             ...        ...      ...           ...            ...
# 3328            192        0.0      1.0          36.0          156.2
# 3329             68        0.0      0.0           0.0          231.1
# 3330             28        0.0      0.0           0.0          180.8
# 3331            184        1.0      0.0           0.0          213.8
# 3332             74        0.0      1.0          25.0          234.4
#
#       Total_llama_dia  Total_cargas_dia  Total_min_manana  Total_llama_manana  \
# ...
