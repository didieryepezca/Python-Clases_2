# %%
import pandas as pda

# %%
import sys
sys.path
# Out:
# ['D:\\CERTIFIED BIG DATA DEVELOPER\\2020-02-21_Python',
#  'C:\\ProgramData\\Anaconda3\\python37.zip',
#  'C:\\ProgramData\\Anaconda3\\DLLs',
#  'C:\\ProgramData\\Anaconda3\\lib',
#  'C:\\ProgramData\\Anaconda3',
#  '',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\LENOVO\\.ipython']

# %%
data = pda.read_csv('D:\\CERTIFIED BIG DATA DEVELOPER\\2020-02-21_Python/Data_Carros.csv', sep=',', skiprows = 3)
data
# Out:
#            Modelo_Marca  Perdidas_Normal Tipo_Combustible Aspiracion  \
# 0    C001_mercedes-benz              NaN              gas        std
# 1              C002_bmw              NaN              gas        std
# 2    C003_mercedes-benz              NaN              gas        std
# 3          C004_porsche              NaN              gas        std
# 4              C005_bmw              NaN              gas        std
# ..                  ...              ...              ...        ...
# 196     C197_mitsubishi            161.0              gas        std
# 197         C198_toyota             87.0              gas        std
# 198          C199_mazda            104.0              gas        std
# 199      C200_chevrolet            121.0              gas        std
# 200         C201_subaru             83.0              gas        std
#
#     Num_Puertas Estilo_Carroceria Ruedas_Motrices  Distancia_Entre_Ejes  \
# ...
